# %%
import os
ROOT_DIR=os.getcwd()
#print(ROOT_DIR)
import sys
DATA_DIR=os.path.join(ROOT_DIR,"Breast_Cancer_Data")
sys.path.append(DATA_DIR)
os.chdir(DATA_DIR)

# %% [markdown]
# The dataset used in this story is publicly available and was created by Dr. William H. Wolberg, physician at the University Of Wisconsin Hospital at Madison, Wisconsin, USA. To create the dataset Dr. Wolberg used fluid samples, taken from patients with solid breast masses and an easy-to-use graphical computer program called Xcyt, which is capable of perform the analysis of cytological features based on a digital scan. The program uses a curve-fitting algorithm, to compute ten features from each one of the cells in the sample, than it calculates the mean value, extreme value and standard error of each feature for the image, returning a 30 real-valuated vector

# %% [markdown]
# Attribute Information:
#
#     ID number 2) Diagnosis (M = malignant, B = benign) 3–32)
#
# Ten real-valued features are computed for each cell nucleus:
#
#     radius (mean of distances from center to points on the perimeter)
#     texture (standard deviation of gray-scale values)
#     perimeter
#     area
#     smoothness (local variation in radius lengths)
#     compactness (perimeter² / area — 1.0)
#     concavity (severity of concave portions of the contour)
#     concave points (number of concave portions of the contour)
#     symmetry
#     fractal dimension (“coastline approximation” — 1)
#
# The mean, standard error and “worst” or largest (mean of the three largest values) of these features were computed for each image, resulting in 30 features. For instance, field 3 is Mean Radius, field 13 is Radius SE, field 23 is Worst Radius.

# %% [markdown]
#    #  Attribute                     Domain
#    -- -----------------------------------------
#    1. Sample code number            id number
#    2. Clump Thickness               1 - 10
#    3. Uniformity of Cell Size       1 - 10
#    4. Uniformity of Cell Shape      1 - 10
#    5. Marginal Adhesion             1 - 10
#    6. Single Epithelial Cell Size   1 - 10
#    7. Bare Nuclei                   1 - 10
#    8. Bland Chromatin               1 - 10
#    9. Normal Nucleoli               1 - 10
#   10. Mitoses                       1 - 10
#   11. Class:                        (2 for benign	 4 for malignant)
#
# ![image.png](attachment:image.png)

# %%
COLS="""
   1. Sample code number            id number			
   2. Clump Thickness               1 - 10			
   3. Uniformity of Cell Size       1 - 10			
   4. Uniformity of Cell Shape      1 - 10			
   5. Marginal Adhesion             1 - 10			
   6. Single Epithelial Cell Size   1 - 10			
   7. Bare Nuclei                   1 - 10			
   8. Bland Chromatin               1 - 10			
   9. Normal Nucleoli               1 - 10			
  10. Mitoses                       1 - 10			
  11. Class:
"""

# %%
HEADS=[]
for each_line in COLS.splitlines():
    try:
        
        print(each_line.split()[2])
    except:
        continue
# Out:
# code
# Thickness
# of
# of
# Adhesion
# Epithelial
# Nuclei
# Chromatin
# Nucleoli
# 1

# %%
COL_NAMES="""
ID
Clump_Thickness
Cell_Size_Uniformity
Cell_Shape_Uniformity
Marginal_Adhesion
Single_Epithelial_Cell_Size
Bare_Nuclei
Bland_Chromatin
Normal_Nucleoli
Mitoses
Class
"""
COL_NAMES=COL_NAMES.strip()
COL_NAMES=COL_NAMES.splitlines()
map(str.strip, COL_NAMES)

# %%
COL_NAMES
# Out:
# ['ID',
#  'Clump_Thickness',
#  'Cell_Size_Uniformity',
#  'Cell_Shape_Uniformity',
#  'Marginal_Adhesion',
#  'Single_Epithelial_Cell_Size',
#  'Bare_Nuclei',
#  'Bland_Chromatin',
#  'Normal_Nucleoli',
#  'Mitoses',
#  'Class']

# %%
def loader(FILENAME,COLS):
    COL_NAMES=COLS.strip()
    COL_NAMES=COL_NAMES.splitlines()
    map(str.strip, COL_NAMES)
    
    dfload = pd.read_csv(FILENAME,names=COL_NAMES, header=None)
    
    return dfload

# %%
#importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

#importing our cancer dataset
COL_NAMES="""
ID
Clump_Thickness
Cell_Size_Uniformity
Cell_Shape_Uniformity
Marginal_Adhesion
Single_Epithelial_Cell_Size
Bare_Nuclei
Bland_Chromatin
Normal_Nucleoli
Mitoses
Class
"""
#1. Title: Wisconsin Breast Cancer Database (January 8  1991)
dfold = loader(FILENAME="breast-cancer-wisconsin_data.csv",COLS=COL_NAMES)

# %%
dfold.head(10)
# Out:
#         ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0  1000025                5                     1                      1
# 1  1002945                5                     4                      4
# 2  1015425                3                     1                      1
# 3  1016277                6                     8                      8
# 4  1017023                4                     1                      1
# 5  1017122                8                    10                     10
# 6  1018099                1                     1                      1
# 7  1018561                2                     1                      2
# 8  1033078                2                     1                      1
# 9  1033078                4                     2                      1
#
#    Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# 0                  1                            2           1
# ...

# %%
dfold["Class"].value_counts()
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %% [markdown]
#   11. Class:                        (2 for benign  4 for malignant)

# %%
print("Cancer data set dimensions : {}".format(dfold.shape))
# Out:
# Cancer data set dimensions : (699, 11)

# %%
#importing our cancer dataset
COL_NAMES="""
ID
Clump_Thickness
Cell_Size_Uniformity
Cell_Shape_Uniformity
Marginal_Adhesion
Single_Epithelial_Cell_Size
Bare_Nuclei
Bland_Chromatin
Normal_Nucleoli
Mitoses
Class
"""
#1. Title: Wisconsin Breast Cancer Database (January 8  1991)
dfold = loader(FILENAME="breast-cancer-wisconsin_data.csv",COLS=COL_NAMES)

# %%
dfkaggle=pd.read_csv("data.csv")
dfkaggle.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
lst = ['Unnamed: 32']
dfkaggle = dfkaggle.drop(lst,axis = 1 )
df.head()
# Out:
#         ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0  1000025                5                     1                      1
# 1  1002945                5                     4                      4
# 2  1015425                3                     1                      1
# 3  1016277                6                     8                      8
# 4  1017023                4                     1                      1
#
#    Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# 0                  1                            2           1
# 1                  5                            7          10
# 2                  1                            2           2
# 3                  1                            3           4
# 4                  3                            2           1
#
#    Bland_Chromatin  Normal_Nucleoli  Mitoses  Class
# 0                3                1        1      2
# ...

# %%
dfkaggle.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
MAIN_COLS=list(dfkaggle.columns)
len(MAIN_COLS)
# Out:
# 32

# %%
#1. Title: Wisconsin Diagnostic Breast Cancer (WDBC)
dfdiag = pd.read_csv("wdbc_data.csv",names=MAIN_COLS, header=None)
dfdiag.head(8)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760         0.30010              0.14710
# 1          0.08474           0.07864         0.08690              0.07017
# ...

# %%
MAIN_COLS
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %% [markdown]
# Overview
#
# Recurrent breast cancer is breast cancer that comes back after initial treatment. Although the initial treatment is aimed at eliminating all cancer cells, a few may have evaded treatment and survived. These undetected cancer cells multiply, becoming recurrent breast cancer.
#
# Recurrent breast cancer may occur months or years after your initial treatment. The cancer may come back in the same place as the original cancer (local recurrence), or it may spread to other areas of your body (distant recurrence).
#
# Learning you have recurrent breast cancer may be harder than dealing with the initial diagnosis. But having recurrent breast cancer is far from hopeless. Treatment may eliminate local, regional or distant recurrent breast cancer. Even if a cure isn't possible, treatment may control the disease for long periods of time.

# %% [markdown]
# COLUMS ADDED ARE
# 34) Tumor size - diameter of the excised tumor in centimeters
# 35) Lymph node status - number of positive axillary lymph nodes
# observed at time of surgery
# ![image.png](attachment:image.png)

# %%
TO_APPEND=['Tumor_size','Lymph_node_status']

# %%
COLS=MAIN_COLS+TO_APPEND
COLS.insert(2, "TIME")  
COLS
# Out:
# ['id',
#  'diagnosis',
#  'TIME',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  'Tumor_size',
#  'Lymph_node_status']

# %%
len(COLS)
# Out:
# 35

# %%
#1. Title: Wisconsin Prognostic Breast Cancer (WPBC)
dfprog = pd.read_csv("wpbc_data.csv",names=COLS, header=None)
dfprog.head(8)
#New field time indicating the time of recurrence of the breast cancer
# Out:
#        id diagnosis  TIME  radius_mean  texture_mean  perimeter_mean  \
# 0  119513         N    31        18.02         27.60          117.50
# 1    8423         N    61        17.99         10.38          122.80
# 2  842517         N   116        21.37         17.44          137.50
# 3  843483         N   123        11.42         20.38           77.58
# 4  843584         R    27        20.29         14.34          135.10
# 5  843786         R    77        12.75         15.29           84.60
# 6  844359         N    60        18.98         19.61          124.40
# 7  844582         R    77        13.71         20.83           90.20
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# 0     1013.0          0.09489            0.1036         0.10860  ...
# 1     1001.0          0.11840            0.2776         0.30010  ...
# 2     1373.0          0.08836            0.1189         0.12550  ...
# ...

# %%
dfdiag
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dfkaggle
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dfold
# Out:
#           ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
#      Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# ...

# %%
dfold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           699 non-null    int64
#  1   Clump_Thickness              699 non-null    int64
#  2   Cell_Size_Uniformity         699 non-null    int64
#  3   Cell_Shape_Uniformity        699 non-null    int64
#  4   Marginal_Adhesion            699 non-null    int64
#  5   Single_Epithelial_Cell_Size  699 non-null    int64
#  6   Bare_Nuclei                  699 non-null    object
#  7   Bland_Chromatin              699 non-null    int64
#  8   Normal_Nucleoli              699 non-null    int64
#  9   Mitoses                      699 non-null    int64
#  10  Class                        699 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 60.2+ KB

# %%
dfold.Bare_Nuclei  = dfold.Bare_Nuclei .replace({"?": np.nan})

# %%
dfold=dfold.dropna()

#df = df.apply (pd.to_numeric, errors='coerce')
#df = df.dropna()

# %%
dfold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 683 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           683 non-null    int64
#  1   Clump_Thickness              683 non-null    int64
#  2   Cell_Size_Uniformity         683 non-null    int64
#  3   Cell_Shape_Uniformity        683 non-null    int64
#  4   Marginal_Adhesion            683 non-null    int64
#  5   Single_Epithelial_Cell_Size  683 non-null    int64
#  6   Bare_Nuclei                  683 non-null    object
#  7   Bland_Chromatin              683 non-null    int64
#  8   Normal_Nucleoli              683 non-null    int64
#  9   Mitoses                      683 non-null    int64
#  10  Class                        683 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 64.0+ KB

# %%
dfprog
# Out:
#          id diagnosis  TIME  radius_mean  texture_mean  perimeter_mean  \
# 0    119513         N    31        18.02         27.60          117.50
# 1      8423         N    61        17.99         10.38          122.80
# 2    842517         N   116        21.37         17.44          137.50
# 3    843483         N   123        11.42         20.38           77.58
# 4    843584         R    27        20.29         14.34          135.10
# ..      ...       ...   ...          ...           ...             ...
# 193  942640         N    10        22.52         21.92          146.90
# 194  943471         N     8        15.44         31.18          101.00
# 195   94547         N    12        17.17         29.19          110.00
# 196  947204         R     3        21.42         22.84          145.00
# 197  947489         N     6        16.70         28.13          110.30
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# ...

# %%
dfprog.Lymph_node_status.value_counts()
# Out:
# 0     87
# 1     35
# 2     17
# 4     10
# 7      6
# 13     6
# 9      4
# 3      4
# ?      4
# 6      3
# 15     3
# 11     3
# 10     2
# 8      2
# 20     2
# 5      2
# 27     2
# 17     1
# 24     1
# 18     1
# 16     1
# 14     1
# 21     1
# Name: Lymph_node_status, dtype: int64

# %%
dfkaggle.equals(dfdiag)
# Out:
# True

# %% [markdown]
# ## SOME PREPROCESSING REQ

# %%
import numpy as np
dfprog.Lymph_node_status = dfprog.Lymph_node_status.replace({"?": np.nan})

# %%
dfprog
# Out:
#          id diagnosis  TIME  radius_mean  texture_mean  perimeter_mean  \
# 0    119513         N    31        18.02         27.60          117.50
# 1      8423         N    61        17.99         10.38          122.80
# 2    842517         N   116        21.37         17.44          137.50
# 3    843483         N   123        11.42         20.38           77.58
# 4    843584         R    27        20.29         14.34          135.10
# ..      ...       ...   ...          ...           ...             ...
# 193  942640         N    10        22.52         21.92          146.90
# 194  943471         N     8        15.44         31.18          101.00
# 195   94547         N    12        17.17         29.19          110.00
# 196  947204         R     3        21.42         22.84          145.00
# 197  947489         N     6        16.70         28.13          110.30
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  ...  \
# ...

# %%
dfprog.Lymph_node_status.value_counts()
# Out:
# 0     87
# 1     35
# 2     17
# 4     10
# 7      6
# 13     6
# 9      4
# 3      4
# 6      3
# 15     3
# 11     3
# 10     2
# 8      2
# 20     2
# 5      2
# 27     2
# 24     1
# 18     1
# 16     1
# 17     1
# 14     1
# 21     1
# Name: Lymph_node_status, dtype: int64

# %%
dfprog.isnull().sum(axis = 0)
# Out:
# id                         0
# diagnosis                  0
# TIME                       0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# ...

# %%
dfold
# Out:
#           ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
#      Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# ...

# %%
dfkaggle.rename(columns = {'id':'ID'}, inplace = True) 
dfkaggle
# Out:
#            ID diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
dfold
# Out:
#           ID  Clump_Thickness  Cell_Size_Uniformity  Cell_Shape_Uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
#      Marginal_Adhesion  Single_Epithelial_Cell_Size Bare_Nuclei  \
# ...

# %%
dfkaggle
# Out:
#            ID diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
# getting intersection of keys
df = pd.merge(dfold, dfkaggle,  on=['ID'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [ID, Clump_Thickness, Cell_Size_Uniformity, Cell_Shape_Uniformity, Marginal_Adhesion, Single_Epithelial_Cell_Size, Bare_Nuclei, Bland_Chromatin, Normal_Nucleoli, Mitoses, Class, diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst]
# Index: []
#
# [0 rows x 42 columns]

# %%
df['C'] = [len(set(a) & set(b)) for a, b in zip(dfold.ID, dfkaggle.ID)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-172-9d5da3d8ccbb> in <module>
# ----> 1 df['C'] = [len(set(a) & set(b)) for a, b in zip(dfold.ID, dfkaggle.ID)]
#
# <ipython-input-172-9d5da3d8ccbb> in <listcomp>(.0)
# ----> 1 df['C'] = [len(set(a) & set(b)) for a, b in zip(dfold.ID, dfkaggle.ID)]
#
# TypeError: 'int' object is not iterable

# %%
df['C'] = [len(set(a).intersection(b)) for a, b in zip(dfold.ID, dfkaggle.ID)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-173-fb1b6ae335de> in <module>
# ----> 1 df['C'] = [len(set(a).intersection(b)) for a, b in zip(dfold.ID, dfkaggle.ID)]
#
# <ipython-input-173-fb1b6ae335de> in <listcomp>(.0)
# ----> 1 df['C'] = [len(set(a).intersection(b)) for a, b in zip(dfold.ID, dfkaggle.ID)]
#
# TypeError: 'int' object is not iterable

# %%
list1,list2=list(dfold.ID), list(dfkaggle.ID)

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 
intersection(list1, list2)
# Out:
# []

# %%
dfkaggle.to_csv("diagnosis_kaggle_DATA.csv",index=False)
dfold.to_csv("diagnosis_INT_DATA.csv",index=False)
dfprog.to_csv("prognosis_DATA.csv",index=False)
